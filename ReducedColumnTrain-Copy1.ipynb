# %%
import tensorflow_decision_forests as tfdf
import pandas as pd

cols = ['trans_date_trans_time', 'category', 'amt', 'first', 'last', 'city', 'state', 'zip', 'dob', 'is_fraud']
# Load the dataset in a Pandas dataframe.
train_df = pd.read_csv("archive/fraudTrain.csv", usecols = cols)
test_df = pd.read_csv("archive/fraudTest.csv", usecols = cols)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label="is_fraud")
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label="is_fraud")

# Train the model
model = tfdf.keras.GradientBoostedTreesModel()
model.fit(train_ds)

# Look at the model.
model.summary()
# Out:
# 2022-10-14 20:04:21.231165: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-14 20:04:21.548944: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:21.548956: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-14 20:04:21.590693: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-14 20:04:22.418708: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:22.418776: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:22.418781: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/jesse/miniconda3/envs/ft/lib/python3.10/site-packages/tensorflow_decision_forests/keras/core_inference.py:873: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   features_dataframe = dataframe.drop(label, 1)
# 2022-10-14 20:04:27.137102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-10-14 20:04:27.137192: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137235: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137269: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137302: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137335: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137367: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137400: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137432: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-10-14 20:04:27.137438: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-10-14 20:04:27.140055: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Use /tmp/tmpxmqclfi2 as temporary training directory
# Reading training dataset...
# /home/jesse/miniconda3/envs/ft/lib/python3.10/site-packages/tensorflow_decision_forests/keras/core_inference.py:873: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   features_dataframe = dataframe.drop(label, 1)
# Training dataset read in 0:00:05.289878. Found 1296675 examples.
# Training model...
# Model trained in 0:01:42.657837
# Compiling model...
# [INFO kernel.cc:1176] Loading model from path /tmp/tmpxmqclfi2/model/ with prefix 6128e4aba67549db
# [INFO abstract_model.cc:1248] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO kernel.cc:1022] Use fast generic engine
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f5079fe7eb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f5079fe7eb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f5079fe7eb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (9):
# 	amt
# 	category
# 	city
# 	dob
# 	first
# 	last
# 	state
# 	trans_date_trans_time
# 	zip
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1. "trans_date_trans_time"  4.922668 ################
#     2.               "__LABEL"  4.922668 ################
#     3.                   "zip"  4.890853 ###############
#     4.                 "first"  4.281620 #############
#     5.                  "last"  3.940629 ############
#     6.                  "city"  3.858896 ############
#     7.                   "dob"  3.791297 ###########
#     8.              "category"  3.517768 ##########
#     9.                 "state"  3.318687 ##########
#    10.                   "amt"  0.588247
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "amt" 55.000000 ################
#     2.   "dob" 19.000000 ###
#     3.  "last" 18.000000 ###
#     4.  "city" 14.000000 ##
#     5. "state" 13.000000 #
#     6. "first"  8.000000
#
# Variable Importance: NUM_NODES:
#     1.      "amt" 1233.000000 ################
#     2.    "state" 777.000000 ##########
#     3. "category" 460.000000 #####
#     4.      "dob" 297.000000 ###
#     5.     "city" 266.000000 ###
#     6.    "first" 237.000000 ##
#     7.     "last" 229.000000 ##
#     8.      "zip"  9.000000
#
# Variable Importance: SUM_SCORE:
#     1. "category" 5478.883101 ################
#     2.      "amt" 3534.744585 ##########
#     3.    "state" 1085.370290 ###
#     4.      "dob" 355.852417 #
#     5.    "first" 330.232460
#     6.     "city" 309.155938
#     7.     "last" 282.138642
#     8.      "zip"  1.426793
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0186373
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 127
# Total number of nodes: 7143
#
# Number of nodes by tree:
# Count: 127 Average: 56.2441 StdDev: 9.07685
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 13  10.24%  10.24% ###
# [ 34, 36)  0   0.00%  10.24%
# [ 36, 37)  0   0.00%  10.24%
# [ 37, 39)  0   0.00%  10.24%
# [ 39, 40)  0   0.00%  10.24%
# [ 40, 42)  1   0.79%  11.02%
# [ 42, 43)  0   0.00%  11.02%
# [ 43, 45)  1   0.79%  11.81%
# [ 45, 46)  0   0.00%  11.81%
# [ 46, 48)  2   1.57%  13.39%
# [ 48, 50)  2   1.57%  14.96%
# [ 50, 51)  0   0.00%  14.96%
# [ 51, 53)  5   3.94%  18.90% #
# [ 53, 54)  9   7.09%  25.98% ##
# [ 54, 56)  6   4.72%  30.71% #
# [ 56, 57)  0   0.00%  30.71%
# [ 57, 59) 14  11.02%  41.73% ###
# [ 59, 60) 12   9.45%  51.18% ###
# [ 60, 62) 18  14.17%  65.35% ####
# [ 62, 63] 44  34.65% 100.00% ##########
#
# Depth by leafs:
# Count: 3635 Average: 4.93508 StdDev: 0.35984
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)   13   0.36%   0.36%
# [ 2, 3)    3   0.08%   0.44%
# [ 3, 4)   38   1.05%   1.49%
# [ 4, 5)   99   2.72%   4.21%
# [ 5, 5] 3482  95.79% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3635 Average: 40771.9 StdDev: 146598
# Min: 5 Max: 1164409 Ignored: 0
# ----------------------------------------------
# [       5,   58225) 3220  88.58%  88.58% ##########
# [   58225,  116445)  109   3.00%  91.58%
# [  116445,  174665)   60   1.65%  93.23%
# [  174665,  232886)   43   1.18%  94.42%
# [  232886,  291106)   31   0.85%  95.27%
# [  291106,  349326)   18   0.50%  95.76%
# [  349326,  407546)    9   0.25%  96.01%
# [  407546,  465767)    9   0.25%  96.26%
# [  465767,  523987)   15   0.41%  96.67%
# [  523987,  582207)   37   1.02%  97.69%
# [  582207,  640427)   44   1.21%  98.90%
# [  640427,  698648)   11   0.30%  99.20%
# [  698648,  756868)    0   0.00%  99.20%
# [  756868,  815088)    0   0.00%  99.20%
# [  815088,  873308)    1   0.03%  99.23%
# [  873308,  931529)    2   0.06%  99.28%
# [  931529,  989749)    0   0.00%  99.28%
# [  989749, 1.04797e+06)    0   0.00%  99.28%
# [ 1.04797e+06, 1.10619e+06)    0   0.00%  99.28%
# [ 1.10619e+06, 1.16441e+06]   26   0.72% 100.00%
#
# Attribute in nodes:
# 	1233 : amt [NUMERICAL]
# 	777 : state [CATEGORICAL]
# 	460 : category [CATEGORICAL]
# 	297 : dob [CATEGORICAL]
# 	266 : city [CATEGORICAL]
# 	237 : first [CATEGORICAL]
# 	229 : last [CATEGORICAL]
# 	9 : zip [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	55 : amt [NUMERICAL]
# 	19 : dob [CATEGORICAL]
# 	18 : last [CATEGORICAL]
# 	14 : city [CATEGORICAL]
# 	13 : state [CATEGORICAL]
# 	8 : first [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	223 : amt [NUMERICAL]
# 	48 : category [CATEGORICAL]
# 	26 : city [CATEGORICAL]
# 	24 : dob [CATEGORICAL]
# 	22 : last [CATEGORICAL]
# 	14 : state [CATEGORICAL]
# 	10 : first [CATEGORICAL]
# 	1 : zip [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	473 : amt [NUMERICAL]
# 	119 : category [CATEGORICAL]
# 	76 : state [CATEGORICAL]
# 	57 : city [CATEGORICAL]
# 	52 : dob [CATEGORICAL]
# 	36 : last [CATEGORICAL]
# 	31 : first [CATEGORICAL]
# 	3 : zip [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	744 : amt [NUMERICAL]
# 	360 : state [CATEGORICAL]
# 	264 : category [CATEGORICAL]
# 	113 : city [CATEGORICAL]
# 	110 : dob [CATEGORICAL]
# 	87 : last [CATEGORICAL]
# 	84 : first [CATEGORICAL]
# 	5 : zip [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1233 : amt [NUMERICAL]
# 	777 : state [CATEGORICAL]
# 	460 : category [CATEGORICAL]
# 	297 : dob [CATEGORICAL]
# 	266 : city [CATEGORICAL]
# 	237 : first [CATEGORICAL]
# 	229 : last [CATEGORICAL]
# 	9 : zip [NUMERICAL]
#
# Condition type in nodes:
# 	2083 : ContainsBitmapCondition
# 	1242 : HigherCondition
# 	183 : ContainsCondition
# Condition type in nodes with depth <= 0:
# 	59 : ContainsBitmapCondition
# 	55 : HigherCondition
# 	13 : ContainsCondition
# Condition type in nodes with depth <= 1:
# 	224 : HigherCondition
# 	131 : ContainsBitmapCondition
# 	13 : ContainsCondition
# Condition type in nodes with depth <= 2:
# 	476 : HigherCondition
# 	356 : ContainsBitmapCondition
# 	15 : ContainsCondition
# Condition type in nodes with depth <= 3:
# 	973 : ContainsBitmapCondition
# 	749 : HigherCondition
# 	45 : ContainsCondition
# Condition type in nodes with depth <= 5:
# 	2083 : ContainsBitmapCondition
# 	1242 : HigherCondition
# 	183 : ContainsCondition

# %%
model.compile(metrics=["accuracy"])
evaluation = model.evaluate(test_ds, return_dict=True)
print()

for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 556/556 [==============================] - 2s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9972
#
# loss: 0.0000
# accuracy: 0.9972

# %%
model.save('my_model')
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# [INFO kernel.cc:1176] Loading model from path my_model/assets/ with prefix 7e3b7aea232c4386
# [INFO abstract_model.cc:1248] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO kernel.cc:1022] Use fast generic engine
# 556/556 [==============================] - 2s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9972
#
# loss: 0.0000
# accuracy: 0.9972
